# %%
import seaborn as sbn
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#Lineplot

# %%
data=sbn.load_dataset("fmri")
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
data.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
data.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
data.shape
# Out:
# (1064, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
data.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
data.describe().transpose()
# Out:
#             count     mean       std       min      25%       50%        75%  \
# timepoint  1064.0  9.00000  5.479801  0.000000  4.00000  9.000000  14.000000
# signal     1064.0  0.00354  0.093930 -0.255486 -0.04607 -0.013653   0.024293
#
#                  max
# timepoint  18.000000
# signal      0.564985

# %%
data.describe(include="all").transpose()
# Out:
#             count unique       top freq     mean       std       min      25%  \
# subject      1064     14       s13   76      NaN       NaN       NaN      NaN
# timepoint  1064.0    NaN       NaN  NaN      9.0  5.479801       0.0      4.0
# event        1064      2      stim  532      NaN       NaN       NaN      NaN
# region       1064      2  parietal  532      NaN       NaN       NaN      NaN
# signal     1064.0    NaN       NaN  NaN  0.00354   0.09393 -0.255486 -0.04607
#
#                 50%       75%       max
# subject         NaN       NaN       NaN
# timepoint       9.0      14.0      18.0
# event           NaN       NaN       NaN
# region          NaN       NaN       NaN
# signal    -0.013653  0.024293  0.564985

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.lineplot(x="timepoint",y="signal",data=data)
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.lineplot(x="timepoint",y="signal",data=data,hue="event")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.lineplot(x="timepoint",y="signal",data=data,hue="event",style="event")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.lineplot(x="timepoint",y="signal",data=data,hue="event",style="event",markers=True)
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Barplot

# %%
import pandas as pd

# %%
sbn.set(style="darkgrid")

# %%
data=pd.read_csv("pokemon.csv")
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %%
data.describe(include="all").transpose()
# Out:
#             count unique        top freq       mean         std    min  \
# #           800.0    NaN        NaN  NaN  362.81375  208.343798    1.0
# Name          800    800  Bulbasaur    1        NaN         NaN    NaN
# Type 1        800     18      Water  112        NaN         NaN    NaN
# Type 2        414     18     Flying   97        NaN         NaN    NaN
# Total       800.0    NaN        NaN  NaN   435.1025   119.96304  180.0
# HP          800.0    NaN        NaN  NaN   69.25875   25.534669    1.0
# Attack      800.0    NaN        NaN  NaN   79.00125   32.457366    5.0
# Defense     800.0    NaN        NaN  NaN    73.8425   31.183501    5.0
# Sp. Atk     800.0    NaN        NaN  NaN      72.82   32.722294   10.0
# Sp. Def     800.0    NaN        NaN  NaN    71.9025   27.828916   20.0
# Speed       800.0    NaN        NaN  NaN    68.2775   29.060474    5.0
# Generation  800.0    NaN        NaN  NaN    3.32375     1.66129    1.0
# ...

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Attack",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Defense",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data)
plt.show()

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data,hue="Type 1")
plt.legend(loc="right")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data,hue="Type 1")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data,hue="Type 2")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data,palette="Blues_d")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Attack",data=data,palette="rocket")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Defense",data=data,palette="vlag")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.barplot(x="Legendary",y="Speed",data=data,color="magenta")
plt.show()

# %%
#Scatterplot

# %%
data=pd.read_csv("iris.csv")
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe().transpose()
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
data.describe(include="all").transpose()
# Out:
#               count unique     top freq      mean       std  min  25%   50%  \
# Sepal.Length  150.0    NaN     NaN  NaN  5.843333  0.828066  4.3  5.1   5.8
# Sepal.Width   150.0    NaN     NaN  NaN  3.057333  0.435866  2.0  2.8   3.0
# Petal.Length  150.0    NaN     NaN  NaN     3.758  1.765298  1.0  1.6  4.35
# Petal.Width   150.0    NaN     NaN  NaN  1.199333  0.762238  0.1  0.3   1.3
# Species         150      3  setosa   50       NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# Sepal.Length  6.4  7.9
# Sepal.Width   3.3  4.4
# Petal.Length  5.1  6.9
# Petal.Width   1.8  2.5
# Species       NaN  NaN

# %%
sbn.set(style="white")

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Length",y="Sepal.Width",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Petal.Length",y="Petal.Width",data=data,color="green")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Petal.Length",y="Petal.Length",data=data,hue="Species",style="Species")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Length",y="Sepal.Length",data=data,hue="Species",style="Species")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Width",y="Sepal.Width",data=data,hue="Species",style="Species")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Petal.Width",y="Petal.Width",data=data,hue="Species",style="Species")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Length",y="Petal.Length",data=data,hue="Species",style="Species")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Length",y="Sepal.Width",data=data,hue="Petal.Length",style="Petal.Length")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.scatterplot(x="Sepal.Length",y="Sepal.Width",data=data,hue="Petal.Width",style="Petal.Width")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
#Histogram/Distplot

# %%
data=pd.read_csv("diamonds.csv")
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.shape
# Out:
# (53940, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data.describe().transpose()
# Out:
#               count          mean           std    min       25%       50%  \
# Unnamed: 0  53940.0  26970.500000  15571.281097    1.0  13485.75  26970.50
# carat       53940.0      0.797940      0.474011    0.2      0.40      0.70
# depth       53940.0     61.749405      1.432621   43.0     61.00     61.80
# table       53940.0     57.457184      2.234491   43.0     56.00     57.00
# price       53940.0   3932.799722   3989.439738  326.0    950.00   2401.00
# x           53940.0      5.731157      1.121761    0.0      4.71      5.70
# y           53940.0      5.734526      1.142135    0.0      4.72      5.71
# z           53940.0      3.538734      0.705699    0.0      2.91      3.53
#
#                  75%       max
# Unnamed: 0  40455.25  53940.00
# carat           1.04      5.01
# depth          62.50     79.00
# table          59.00     95.00
# price        5324.25  18823.00
# x               6.54     10.74
# y               6.54     58.90
# z               4.04     31.80

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.distplot(data["price"],color="red")
plt.show()
# Out:
# C:\Users\sony\AppData\Local\Temp\ipykernel_10988\3286884665.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data["price"],color="red")
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.distplot(data["price"],color="green",hist=False)
plt.show()
# Out:
# C:\Users\sony\AppData\Local\Temp\ipykernel_10988\17899697.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data["price"],color="green",hist=False)
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.distplot(data["price"],color="magenta",kde=False)
plt.show()
# Out:
# C:\Users\sony\AppData\Local\Temp\ipykernel_10988\1140558887.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data["price"],color="magenta",kde=False)

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.distplot(data["price"],color="purple",kde=False,bins=10)
plt.show()
# Out:
# C:\Users\sony\AppData\Local\Temp\ipykernel_10988\766603441.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data["price"],color="purple",kde=False,bins=10)

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.distplot(data["price"],color="orange",kde=False,bins=10,vertical=True)
plt.show()
# Out:
# C:\Users\sony\AppData\Local\Temp\ipykernel_10988\1761118157.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data["price"],color="orange",kde=False,bins=10,vertical=True)

# %%
#JointPlot

# %%
data=pd.read_csv("iris.csv")
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.jointplot(x="Sepal.Length",y="Petal.Length",data=data,color="indigo")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.jointplot(x="Sepal.Width",y="Petal.Width",data=data,color="crimson")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.jointplot(x="Sepal.Length",y="Petal.Length",data=data,color="olive",kind="reg")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.jointplot(x="Sepal.Width",y="Petal.Width",data=data,color="seagreen",kind="reg")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Boxplot

# %%
data=pd.read_csv("churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe().transpose()
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="Churn",y="tenure",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="InternetService",y="MonthlyCharges",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="Contract",y="tenure",data=data,palette="Set1")
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="Contract",y="tenure",data=data,palette="Set1",linewidth=3)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="Contract",y="tenure",data=data,palette="Set1",linewidth=3,order=["Two year","One year","Month-to-month"])
plt.show()

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.boxplot(x="Contract",y="tenure",data=data,hue="PaymentMethod")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
#EDA

# %%
data=pd.read_csv("battles.csv")
data.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
data.shape
# Out:
# (38, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
data.describe().transpose()
# Out:
#                count         mean           std    min      25%     50%  \
# year            38.0   299.105263      0.689280  298.0   299.00   299.0
# battle_number   38.0    19.500000     11.113055    1.0    10.25    19.5
# defender_3       0.0          NaN           NaN    NaN      NaN     NaN
# defender_4       0.0          NaN           NaN    NaN      NaN     NaN
# major_death     37.0     0.351351      0.483978    0.0     0.00     0.0
# major_capture   37.0     0.297297      0.463373    0.0     0.00     0.0
# attacker_size   24.0  9942.541667  20283.092065   20.0  1375.00  4000.0
# defender_size   19.0  6428.157895   6225.182106  100.0  1070.00  6000.0
# summer          37.0     0.702703      0.463373    0.0     0.00     1.0
#
#                     75%       max
# year             300.00     300.0
# battle_number     28.75      38.0
# defender_3          NaN       NaN
# defender_4          NaN       NaN
# major_death        1.00       1.0
# major_capture      1.00       1.0
# ...

# %%
data.describe(include="all").transpose()
# Out:
#                    count unique  \
# name                  38     38
# year                38.0    NaN
# battle_number       38.0    NaN
# attacker_king         36      4
# defender_king         35      6
# attacker_1            38     11
# attacker_2            10      7
# attacker_3             3      2
# attacker_4             2      1
# defender_1            37     12
# defender_2             2      2
# defender_3           0.0    NaN
# defender_4           0.0    NaN
# attacker_outcome      37      2
# battle_type           37      4
# major_death         37.0    NaN
# major_capture       37.0    NaN
# attacker_size       24.0    NaN
# defender_size       19.0    NaN
# attacker_commander    37     31
# defender_commander    28     28
# summer              37.0    NaN
# location              37     27
# region                38      7
# note                   5      5
#
#                                                                   top freq  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
data["attacker_king"].value_counts()
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: count, dtype: int64

# %%
data["defender_king"].value_counts()
# Out:
# defender_king
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
data["name"].value_counts()
# Out:
# name
# Battle of the Golden Tooth                              1
# Fall of Moat Cailin                                     1
# Battle of Duskendale                                    1
# Battle of the Burning Septry                            1
# Battle of the Ruby Ford                                 1
# Retaking of Harrenhal                                   1
# The Red Wedding                                         1
# Siege of Seagard                                        1
# Battle of Castle Black                                  1
# Sack of Saltpans                                        1
# Battle at the Mummer's Ford                             1
# Retaking of Deepwood Motte                              1
# Battle of the Shield Islands                            1
# Invasion of Ryamsport, Vinetown, and Starfish Harbor    1
# Second Seige of Storm's End                             1
# Siege of Dragonstone                                    1
# ...

# %%
data["attacker_commander"].value_counts()
# Out:
# attacker_commander
# Gregor Clegane                                                                                     4
# Theon Greyjoy                                                                                      2
# Robb Stark, Brynden Tully                                                                          2
# Euron Greyjoy, Victarion Greyjoy                                                                   2
# Rorge                                                                                              1
# Walder Frey, Roose Bolton, Walder Rivers                                                           1
# Walder Frey                                                                                        1
# Mance Rayder, Tormund Giantsbane, Harma Dogshead, Magnar Styr, Varamyr                             1
# Ramsey Bolton                                                                                      1
# ...

# %%
data["defender_commander"].value_counts()
# Out:
# defender_commander
# Clement Piper, Vance                                                                                             1
# Beric Dondarrion                                                                                                 1
# Tytos Blackwood                                                                                                  1
# Brynden Tully                                                                                                    1
# Rolland Storm                                                                                                    1
# Gilbert Farring                                                                                                  1
# Asha Greyjoy                                                                                                     1
# Stannis Baratheon, Jon Snow, Donal Noye, Cotter Pyke                                                             1
# ...

# %%
data["location"].value_counts()
# Out:
# location
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
data["region"].value_counts()
# Out:
# region
# The Riverlands     17
# The North          10
# The Westerlands     3
# The Stormlands      3
# The Crownlands      2
# The Reach           2
# Beyond the Wall     1
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
sbn.set(rc={"figure.figsize":(10,4)})
sbn.barplot(x="attacker_king",y="attacker_size",data=data)
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
sbn.set(rc={"figure.figsize":(15,4)})
sbn.barplot(x="defender_king",y="defender_size",data=data,palette="Set1")
plt.show()
# Out:
# C:\Users\sony\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
data.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
sbn.set(rc={"figure.figsize":(10,4)})
sbn.countplot(x="attacker_king",hue="battle_type",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(15,4)})
sbn.countplot(x="defender_king",hue="battle_type",data=data)
plt.show()

# %%
data=pd.read_csv("character-deaths.csv")
data.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
data.columns
# Out:
# Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
data.shape
# Out:
# (917, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                917 non-null    object
#  1   Allegiances         664 non-null    object
#  2   Death Year          305 non-null    float64
#  3   Book of Death       307 non-null    float64
#  4   Death Chapter       299 non-null    float64
#  5   Book Intro Chapter  905 non-null    float64
#  6   Gender              917 non-null    int64
#  7   Nobility            917 non-null    int64
#  8   GoT                 917 non-null    int64
#  9   CoK                 917 non-null    int64
#  10  SoS                 917 non-null    int64
#  11  FfC                 917 non-null    int64
#  12  DwD                 917 non-null    int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 93.3+ KB

# %%
data.describe().transpose()
# Out:
#                     count        mean        std    min    25%    50%    75%  \
# Death Year          305.0  299.157377   0.703483  297.0  299.0  299.0  300.0
# Book of Death       307.0    2.928339   1.326482    1.0    2.0    3.0    4.0
# Death Chapter       299.0   40.070234  20.470270    0.0   25.5   39.0   57.0
# Book Intro Chapter  905.0   28.861878  20.165788    0.0   11.0   27.0   43.0
# Gender              917.0    0.828790   0.376898    0.0    1.0    1.0    1.0
# Nobility            917.0    0.468920   0.499305    0.0    0.0    0.0    1.0
# GoT                 917.0    0.272628   0.445554    0.0    0.0    0.0    1.0
# CoK                 917.0    0.353326   0.478264    0.0    0.0    0.0    1.0
# SoS                 917.0    0.424209   0.494492    0.0    0.0    0.0    1.0
# FfC                 917.0    0.272628   0.445554    0.0    0.0    0.0    1.0
# DwD                 917.0    0.284624   0.451481    0.0    0.0    0.0    1.0
#
#                       max
# ...

# %%
data["Name"].value_counts()
# Out:
# Name
# Myles              2
# Addam Marbrand     1
# Othell Yarwyck     1
# Olyvar Frey        1
# Ondrew Locke       1
#                   ..
# Grunt              1
# Gueren             1
# Guncer Sunglass    1
# Guyard Morrigen    1
# Talbert Serry      1
# Name: count, Length: 916, dtype: int64

# %%
data["Allegiances"].value_counts()
# Out:
# Allegiances
# Night's Watch      116
# Lannister           81
# Stark               73
# Baratheon           56
# Greyjoy             51
# Wildling            40
# House Stark         35
# Martell             25
# House Greyjoy       24
# Arryn               23
# Tully               22
# House Lannister     21
# House Targaryen     19
# Targaryen           17
# Tyrell              15
# House Martell       12
# House Tyrell        11
# House Tully          8
# House Baratheon      8
# House Arryn          7
# Name: count, dtype: int64

# %%
data["Gender"].value_counts()
# Out:
# Gender
# 1    760
# 0    157
# Name: count, dtype: int64

# %%
data["Nobility"].value_counts()
# Out:
# Nobility
# 0    487
# 1    430
# Name: count, dtype: int64

# %%
sbn.set(rc={"figure.figsize":(6,4)})
sbn.countplot(x="Death Year",data=data)
plt.show()

# %%
sbn.set(rc={"figure.figsize":(25,8)})
sbn.countplot(x="Allegiances",data=data)
plt.show()
